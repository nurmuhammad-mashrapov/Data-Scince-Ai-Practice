# %%
import pandas as pd
import sqlite3 as sql
from pprint import pprint as print

# %%
! wget https://www.sqlitetutorial.net/wp-content/uploads/2018/03/chinook.zip
# Out:
# --2023-01-31 12:53:40--  https://www.sqlitetutorial.net/wp-content/uploads/2018/03/chinook.zip
# Resolving www.sqlitetutorial.net (www.sqlitetutorial.net)... 151.139.128.10
# Connecting to www.sqlitetutorial.net (www.sqlitetutorial.net)|151.139.128.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 305596 (298K) [application/zip]
# Saving to: ‘chinook.zip’
#
# chinook.zip         100%[===================>] 298.43K   433KB/s    in 0.7s
#
# 2023-01-31 12:53:42 (433 KB/s) - ‘chinook.zip’ saved [305596/305596]

# %%
# !unzip chinook.zip
# Out:
# Archive:  chinook.zip
#   inflating: chinook.db

# %%
db = sql.connect('chinook.db')
cursor = db.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master where type='table';")
cursor.fetchall()
# Out:
# [('albums',),
#  ('sqlite_sequence',),
#  ('artists',),
#  ('customers',),
#  ('employees',),
#  ('genres',),
#  ('invoices',),
#  ('invoice_items',),
#  ('media_types',),
#  ('playlists',),
#  ('playlist_track',),
#  ('tracks',),
#  ('sqlite_stat1',)]

# %%
cursor.execute("SELECT COUNT(*) FROM tracks;")
cursor.fetchone()
# Out:
# (3503,)

# %%
cursor.execute("PRAGMA table_info(tracks);")
cursor.fetchall()
# Out:
# [(0, 'TrackId', 'INTEGER', 1, None, 1),
#  (1, 'Name', 'NVARCHAR(200)', 1, None, 0),
#  (2, 'AlbumId', 'INTEGER', 0, None, 0),
#  (3, 'MediaTypeId', 'INTEGER', 1, None, 0),
#  (4, 'GenreId', 'INTEGER', 0, None, 0),
#  (5, 'Composer', 'NVARCHAR(220)', 0, None, 0),
#  (6, 'Milliseconds', 'INTEGER', 1, None, 0),
#  (7, 'Bytes', 'INTEGER', 0, None, 0),
#  (8, 'UnitPrice', 'NUMERIC(10,2)', 1, None, 0)]

# %%
cursor.execute("SELECT * FROM customers")
cursor.fetchall()
# Out:
# [(1,
#   'Luís',
#   'Gonçalves',
#   'Embraer - Empresa Brasileira de Aeronáutica S.A.',
#   'Av. Brigadeiro Faria Lima, 2170',
#   'São José dos Campos',
#   'SP',
#   'Brazil',
#   '12227-000',
#   '+55 (12) 3923-5555',
#   '+55 (12) 3923-5566',
#   'luisg@embraer.com.br',
#   3),
#  (2,
#   'Leonie',
#   'Köhler',
#   None,
#   'Theodor-Heuss-Straße 34',
#   'Stuttgart',
#   None,
#   'Germany',
#   '70174',
#   '+49 0711 2842222',
#   None,
#   'leonekohler@surfeu.de',
#   5),
#  (3,
#   'François',
#   'Tremblay',
#   None,
#   '1498 rue Bélanger',
#   'Montréal',
#   'QC',
#   'Canada',
#   'H2G 1A7',
#   '+1 (514) 721-4711',
#   None,
#   'ftremblay@gmail.com',
#   3),
#  (4,
#   'Bjørn',
#   'Hansen',
#   None,
#   'Ullevålsveien 14',
#   'Oslo',
#   None,
#   'Norway',
#   '0171',
#   '+47 22 44 22 22',
#   None,
#   'bjorn.hansen@yahoo.no',
#   4),
#  (5,
#   'František',
#   'Wichterlová',
#   'JetBrains s.r.o.',
#   'Klanova 9/506',
#   'Prague',
#   None,
# ...

# %%
df = pd.read_sql_query("SELECT * FROM customers", db)
df
# Out:
#     CustomerId  FirstName      LastName  \
# 0            1       Luís     Gonçalves
# 1            2     Leonie        Köhler
# 2            3   François      Tremblay
# 3            4      Bjørn        Hansen
# 4            5  František   Wichterlová
# 5            6     Helena          Holý
# 6            7     Astrid        Gruber
# 7            8       Daan       Peeters
# 8            9       Kara       Nielsen
# 9           10    Eduardo       Martins
# 10          11  Alexandre         Rocha
# 11          12    Roberto       Almeida
# 12          13   Fernanda         Ramos
# 13          14       Mark       Philips
# 14          15   Jennifer      Peterson
# 15          16      Frank        Harris
# 16          17       Jack         Smith
# 17          18   Michelle        Brooks
# 18          19        Tim         Goyer
# 19          20        Dan        Miller
# 20          21      Kathy         Chase
# 21          22    Heather       Leacock
# ...

# %%
df2 = pd.read_sql("SELECT * FROM artists LIMIT 20", db, index_col='ArtistId')
df2
# Out:
#                                  Name
# ArtistId
# 1                               AC/DC
# 2                              Accept
# 3                           Aerosmith
# 4                   Alanis Morissette
# 5                     Alice In Chains
# 6                Antônio Carlos Jobim
# 7                        Apocalyptica
# 8                          Audioslave
# 9                            BackBeat
# 10                       Billy Cobham
# 11                Black Label Society
# 12                      Black Sabbath
# 13                         Body Count
# 14                    Bruce Dickinson
# 15                          Buddy Guy
# 16                     Caetano Veloso
# 17                      Chico Buarque
# 18        Chico Science & Nação Zumbi
# 19                       Cidade Negra
# 20                       Cláudio Zoli

# %%
df
# Out:
#     CustomerId  FirstName      LastName  \
# 0            1       Luís     Gonçalves
# 1            2     Leonie        Köhler
# 2            3   François      Tremblay
# 3            4      Bjørn        Hansen
# 4            5  František   Wichterlová
# 5            6     Helena          Holý
# 6            7     Astrid        Gruber
# 7            8       Daan       Peeters
# 8            9       Kara       Nielsen
# 9           10    Eduardo       Martins
# 10          11  Alexandre         Rocha
# 11          12    Roberto       Almeida
# 12          13   Fernanda         Ramos
# 13          14       Mark       Philips
# 14          15   Jennifer      Peterson
# 15          16      Frank        Harris
# 16          17       Jack         Smith
# 17          18   Michelle        Brooks
# 18          19        Tim         Goyer
# 19          20        Dan        Miller
# 20          21      Kathy         Chase
# 21          22    Heather       Leacock
# ...

# %%
df3 = pd.read_sql("SELECT CustomerId, FirstName, LastName, Country FROM customers", db)
df3
# Out:
#     CustomerId  FirstName      LastName         Country
# 0            1       Luís     Gonçalves          Brazil
# 1            2     Leonie        Köhler         Germany
# 2            3   François      Tremblay          Canada
# 3            4      Bjørn        Hansen          Norway
# 4            5  František   Wichterlová  Czech Republic
# 5            6     Helena          Holý  Czech Republic
# 6            7     Astrid        Gruber         Austria
# 7            8       Daan       Peeters         Belgium
# 8            9       Kara       Nielsen         Denmark
# 9           10    Eduardo       Martins          Brazil
# 10          11  Alexandre         Rocha          Brazil
# 11          12    Roberto       Almeida          Brazil
# 12          13   Fernanda         Ramos          Brazil
# 13          14       Mark       Philips          Canada
# 14          15   Jennifer      Peterson          Canada
# 15          16      Frank        Harris             USA
# ...

# %%
query = "SELECT CustomerId, FirstName, LastName, Country FROM customers ORDER BY Country, LastName, FirstName"
df4 = pd.read_sql(query, db)
df4
# Out:
#     CustomerId  FirstName      LastName         Country
# 0           56      Diego     Gutiérrez       Argentina
# 1           55       Mark        Taylor       Australia
# 2            7     Astrid        Gruber         Austria
# 3            8       Daan       Peeters         Belgium
# 4           12    Roberto       Almeida          Brazil
# 5            1       Luís     Gonçalves          Brazil
# 6           10    Eduardo       Martins          Brazil
# 7           13   Fernanda         Ramos          Brazil
# 8           11  Alexandre         Rocha          Brazil
# 9           29     Robert         Brown          Canada
# 10          30     Edward       Francis          Canada
# 11          32      Aaron      Mitchell          Canada
# 12          15   Jennifer      Peterson          Canada
# 13          14       Mark       Philips          Canada
# 14          31     Martha          Silk          Canada
# 15          33      Ellie      Sullivan          Canada
# ...

# %%
query = "SELECT  DISTINCT Country FROM customers"
cursor.execute(query)
cursor.fetchall()
# Out:
# [('Brazil',),
#  ('Germany',),
#  ('Canada',),
#  ('Norway',),
#  ('Czech Republic',),
#  ('Austria',),
#  ('Belgium',),
#  ('Denmark',),
#  ('USA',),
#  ('Portugal',),
#  ('France',),
#  ('Finland',),
#  ('Hungary',),
#  ('Ireland',),
#  ('Italy',),
#  ('Netherlands',),
#  ('Poland',),
#  ('Spain',),
#  ('Sweden',),
#  ('United Kingdom',),
#  ('Australia',),
#  ('Argentina',),
#  ('Chile',),
#  ('India',)]

# %%
pd.read_sql(query, db)
# Out:
#            Country
# 0           Brazil
# 1          Germany
# 2           Canada
# 3           Norway
# 4   Czech Republic
# 5          Austria
# 6          Belgium
# 7          Denmark
# 8              USA
# 9         Portugal
# 10          France
# 11         Finland
# 12         Hungary
# 13         Ireland
# 14           Italy
# 15     Netherlands
# 16          Poland
# 17           Spain
# 18          Sweden
# 19  United Kingdom
# 20       Australia
# 21       Argentina
# 22           Chile
# 23           India

# %% [markdown]
# Filter

# %%
query = "SELECT * FROM customers WHERE Country = 'India'"
pd.read_sql(query, db)
# Out:
#    CustomerId FirstName    LastName Company              Address       City  \
# 0          58     Manoj      Pareek    None  12,Community Centre      Delhi
# 1          59      Puja  Srivastava    None    3,Raj Bhavan Road  Bangalore
#
#   State Country PostalCode              Phone   Fax                     Email  \
# 0  None   India     110017  +91 0124 39883988  None   manoj.pareek@rediff.com
# 1  None   India     560001   +91 080 22289999  None  puja_srivastava@yahoo.in
#
#    SupportRepId
# 0             3
# 1             3

# %%
query = "SELECT * FROM customers WHERE Country = 'India' OR Country = 'Germany' ORDER BY Country, LastName, FirstName"
pd.read_sql(query, db)
# Out:
#    CustomerId FirstName    LastName Company                  Address  \
# 0           2    Leonie      Köhler    None  Theodor-Heuss-Straße 34
# 1          36    Hannah   Schneider    None       Tauentzienstraße 8
# 2          38    Niklas    Schröder    None      Barbarossastraße 19
# 3          37      Fynn  Zimmermann    None         Berger Straße 10
# 4          58     Manoj      Pareek    None      12,Community Centre
# 5          59      Puja  Srivastava    None        3,Raj Bhavan Road
#
#         City State  Country PostalCode              Phone   Fax  \
# 0  Stuttgart  None  Germany      70174   +49 0711 2842222  None
# 1     Berlin  None  Germany      10789   +49 030 26550280  None
# 2     Berlin  None  Germany      10779    +49 030 2141444  None
# 3  Frankfurt  None  Germany      60316   +49 069 40598889  None
# 4      Delhi  None    India     110017  +91 0124 39883988  None
# 5  Bangalore  None    India     560001   +91 080 22289999  None
#
# ...

# %%
db.close()

# %%
query = "SELECT * FROM customers WHERE Country = 'India' OR Country = 'Germany' ORDER BY Country, LastName, FirstName"
pd.read_sql(query, db)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[39], line 2
#       1 query = "SELECT * FROM customers WHERE Country = 'India' OR Country = 'Germany' ORDER BY Country, LastName, FirstName"
# ----> 2 pd.read_sql(query, db)
#
# File /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py:564, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     561 pandas_sql = pandasSQL_builder(con)
#     563 if isinstance(pandas_sql, SQLiteDatabase):
# --> 564     return pandas_sql.read_query(
#     565         sql,
#     566         index_col=index_col,
#     567         params=params,
#     568         coerce_float=coerce_float,
#     569         parse_dates=parse_dates,
#     570         chunksize=chunksize,
#     571     )
#     573 try:
#     574     _is_table_name = pandas_sql.has_table(sql)
#
# ...
